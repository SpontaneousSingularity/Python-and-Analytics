# %%
import pandas as pd

# %%
df = pd.read_csv("movies.csv")

# %%
df.head(3)
# Out:
#                                          title   industry  release_year  \
# 0                           The Great Dictator  Hollywood          1940
# 1                     The Fast and the Furious  Hollywood          2001
# 2  Doctor Strange in the Multiverse of Madness  Hollywood          2022
#
#    imdb_rating                            studio  budget  revenue      unit  \
# 0          8.4  Charles Chaplin Film Corporation     2.2      5.0  Millions
# 1          6.8                Universal Pictures    38.0    207.3  Millions
# 2          7.0                    Marvel Studios   200.0    954.8  Millions
#
#   currency language
# 0      USD  English
# 1      USD  English
# 2      USD  English

# %%
import pandas as pd

# %%
df.shape
# Out:
# (40, 10)

# %%
df.industry.head()
# Out:
# 0    Hollywood
# 1    Hollywood
# 2    Hollywood
# 3    Hollywood
# 4    Bollywood
# Name: industry, dtype: object

# %%
df["industry"].head()
# Out:
# 0    Hollywood
# 1    Hollywood
# 2    Hollywood
# 3    Hollywood
# 4    Bollywood
# Name: industry, dtype: object

# %%
df["industry"].value_counts()
# Out:
# industry
# Hollywood    23
# Bollywood    17
# Name: count, dtype: int64

# %%
df["language"].unique()
# Out:
# array(['English', 'Bengali', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df["language"].value_counts()
# Out:
# language
# English    23
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
df[["industry","revenue","language"]].head()
# Out:
#     industry   revenue language
# 0  Hollywood       5.0  English
# 1  Hollywood     207.3  English
# 2  Hollywood     954.8  English
# 3  Hollywood     644.8  English
# 4  Bollywood  100000.0  Bengali

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                           The Great Dictator  Hollywood          1940
# 1                     The Fast and the Furious  Hollywood          2001
# 2  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                        Thor: The Dark World   Hollywood          2013
# 4                              Pather Panchali  Bollywood          1955
#
#    imdb_rating                            studio   budget   revenue  \
# 0          8.4  Charles Chaplin Film Corporation      2.2       5.0
# 1          6.8                Universal Pictures     38.0     207.3
# 2          7.0                    Marvel Studios    200.0     954.8
# 3          6.8                    Marvel Studios    165.0     644.8
# 4          8.3         Government of West Bengal  70000.0  100000.0
#
#         unit currency language
# 0   Millions      USD  English
# 1   Millions      USD  English
# ...

# %%
df.studio.unique()
# Out:
# array(['Charles Chaplin Film Corporation', 'Universal Pictures',
#        'Marvel Studios', 'Government of West Bengal',
#        'Castle Rock Entertainment', 'Warner Bros. Pictures',
#        'Columbia Pictures', 'Universal Pictures  ', 'Paramount Pictures',
#        'Liberty Films', '20th Century Fox', 'Syncopy', nan,
#        'Yash Raj Films', 'Vinod Chopra Films', 'Dharma Productions',
#        'Vinod Chopra Productions', 'Zee Studios', 'Salman Khan Films',
#        'Hombale Films', 'Mythri Movie Makers', 'DVV Entertainment',
#        'Arka Media Works'], dtype=object)

# %%
df.studio.value_counts()
# Out:
# studio
# Marvel Studios                      8
# Universal Pictures                  4
# Vinod Chopra Films                  3
# Dharma Productions                  2
# Paramount Pictures                  2
# Salman Khan Films                   2
# Warner Bros. Pictures               1
# Castle Rock Entertainment           1
# Government of West Bengal           1
# Charles Chaplin Film Corporation    1
# Liberty Films                       1
# 20th Century Fox                    1
# Universal Pictures                  1
# Columbia Pictures                   1
# Yash Raj Films                      1
# Syncopy                             1
# Vinod Chopra Productions            1
# Zee Studios                         1
# Hombale Films                       1
# Mythri Movie Makers                 1
# DVV Entertainment                   1
# Arka Media Works                    1
# Name: count, dtype: int64

# %%
df[df.studio == "Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 2   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                         Thor: The Dark World   Hollywood          2013
# 6                               Thor: Ragnarok   Hollywood          2017
# 7                       Thor: Love and Thunder   Hollywood          2022
# 20                            Avengers: Endgame  Hollywood          2019
# 21                       Avengers: Infinity War  Hollywood          2018
# 22           Captain America: The First Avenger  Hollywood          2011
# 23          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 2           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 3           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 6           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
# Find all movie which were release in between 2012 to 2024
df.info()
df[(df.release_year >= 2012) & (df.release_year <=2024)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         40 non-null     object
#  1   industry      40 non-null     object
#  2   release_year  40 non-null     int64
#  3   imdb_rating   39 non-null     float64
#  4   studio        37 non-null     object
#  5   budget        40 non-null     float64
#  6   revenue       40 non-null     float64
#  7   unit          40 non-null     object
#  8   currency      40 non-null     object
#  9   language      40 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.3+ KB
#                                           title   industry  release_year  \
# 2   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                         Thor: The Dark World   Hollywood          2013
# ...

# %%
df.imdb_rating.max()
df[df.imdb_rating == df.imdb_rating.max()]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 8  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 8  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df.imdb_rating.min()
df[df.imdb_rating == df.imdb_rating.min()]
# Out:
#      title   industry  release_year  imdb_rating             studio  budget  \
# 34  Race 3  Bollywood          2018          1.9  Salman Khan Films     1.8
#
#     revenue      unit currency language
# 34      3.1  Billions      INR    Hindi

# %%
# Find both min and max rating movie
df[(df.imdb_rating == df.imdb_rating.min())|(df.imdb_rating == df.imdb_rating.max())]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 8   The Shawshank Redemption  Hollywood          1994          9.3
# 34                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 8   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 34          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %%
df_min = df[df.imdb_rating == df.imdb_rating.min()]
df_max = df[df.imdb_rating == df.imdb_rating.max()]

pd.concat((df_min,df_max))
# Out:
#                        title   industry  release_year  imdb_rating  \
# 34                    Race 3  Bollywood          2018          1.9
# 8   The Shawshank Redemption  Hollywood          1994          9.3
#
#                        studio  budget  revenue      unit currency language
# 34          Salman Khan Films     1.8      3.1  Billions      INR    Hindi
# 8   Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     40.000000    39.000000     40.000000      40.000000
# mean    2005.100000     7.851282   1931.507000    3819.567500
# std       20.013841     1.216092  11040.716653   15765.741783
# min     1940.000000     1.900000      1.000000       3.100000
# 25%     2000.750000     7.700000     13.425000     173.800000
# 50%     2012.000000     8.100000    142.500000     657.400000
# 75%     2018.000000     8.400000    250.000000    1520.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                           The Great Dictator  Hollywood          1940
# 1                     The Fast and the Furious  Hollywood          2001
# 2  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                        Thor: The Dark World   Hollywood          2013
# 4                              Pather Panchali  Bollywood          1955
#
#    imdb_rating                            studio   budget   revenue  \
# 0          8.4  Charles Chaplin Film Corporation      2.2       5.0
# 1          6.8                Universal Pictures     38.0     207.3
# 2          7.0                    Marvel Studios    200.0     954.8
# 3          6.8                    Marvel Studios    165.0     644.8
# 4          8.3         Government of West Bengal  70000.0  100000.0
#
#         unit currency language
# 0   Millions      USD  English
# 1   Millions      USD  English
# ...

# %%
df[df.currency == "USD"]
# Out:
#                                           title   industry  release_year  \
# 0                            The Great Dictator  Hollywood          1940
# 1                      The Fast and the Furious  Hollywood          2001
# 2   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                         Thor: The Dark World   Hollywood          2013
# 5                              2 Fast 2 Furious  Hollywood          2003
# 6                               Thor: Ragnarok   Hollywood          2017
# 7                       Thor: Love and Thunder   Hollywood          2022
# 8                      The Shawshank Redemption  Hollywood          1994
# 9                                  Interstellar  Hollywood          2014
# 10                     The Pursuit of Happyness  Hollywood          2006
# 11                                    Gladiator  Hollywood          2000
# 12                                      Titanic  Hollywood          1997
# ...

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                           The Great Dictator  Hollywood          1940
# 1                     The Fast and the Furious  Hollywood          2001
# 2  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                        Thor: The Dark World   Hollywood          2013
# 4                              Pather Panchali  Bollywood          1955
#
#    imdb_rating                            studio   budget   revenue  \
# 0          8.4  Charles Chaplin Film Corporation      2.2       5.0
# 1          6.8                Universal Pictures     38.0     207.3
# 2          7.0                    Marvel Studios    200.0     954.8
# 3          6.8                    Marvel Studios    165.0     644.8
# 4          8.3         Government of West Bengal  70000.0  100000.0
#
#         unit currency language
# 0   Millions      USD  English
# 1   Millions      USD  English
# ...

# %%
import datetime as dt

current_year = dt.datetime.now().year
current_year
# Out:
# 2025

# %%
df["age"] = df.apply(lambda row: current_year - row["release_year"],axis=1)

df.head()
# Out:
#                                          title   industry  release_year  \
# 0                           The Great Dictator  Hollywood          1940
# 1                     The Fast and the Furious  Hollywood          2001
# 2  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                        Thor: The Dark World   Hollywood          2013
# 4                              Pather Panchali  Bollywood          1955
#
#    imdb_rating                            studio   budget   revenue  \
# 0          8.4  Charles Chaplin Film Corporation      2.2       5.0
# 1          6.8                Universal Pictures     38.0     207.3
# 2          7.0                    Marvel Studios    200.0     954.8
# 3          6.8                    Marvel Studios    165.0     644.8
# 4          8.3         Government of West Bengal  70000.0  100000.0
#
#         unit currency language  age
# 0   Millions      USD  English   85
# 1   Millions      USD  English   24
# ...

# %%
df["age"] = df.release_year.apply(lambda value: current_year - value)

df.head()
# Out:
#                                          title   industry  release_year  \
# 0                           The Great Dictator  Hollywood          1940
# 1                     The Fast and the Furious  Hollywood          2001
# 2  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                        Thor: The Dark World   Hollywood          2013
# 4                              Pather Panchali  Bollywood          1955
#
#    imdb_rating                            studio   budget   revenue  \
# 0          8.4  Charles Chaplin Film Corporation      2.2       5.0
# 1          6.8                Universal Pictures     38.0     207.3
# 2          7.0                    Marvel Studios    200.0     954.8
# 3          6.8                    Marvel Studios    165.0     644.8
# 4          8.3         Government of West Bengal  70000.0  100000.0
#
#         unit currency language  age
# 0   Millions      USD  English   85
# 1   Millions      USD  English   24
# ...

# %%
df.drop( "age", axis=1, inplace=True)

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                           The Great Dictator  Hollywood          1940
# 1                     The Fast and the Furious  Hollywood          2001
# 2  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                        Thor: The Dark World   Hollywood          2013
# 4                              Pather Panchali  Bollywood          1955
#
#    imdb_rating                            studio   budget   revenue  \
# 0          8.4  Charles Chaplin Film Corporation      2.2       5.0
# 1          6.8                Universal Pictures     38.0     207.3
# 2          7.0                    Marvel Studios    200.0     954.8
# 3          6.8                    Marvel Studios    165.0     644.8
# 4          8.3         Government of West Bengal  70000.0  100000.0
#
#         unit currency language
# 0   Millions      USD  English
# 1   Millions      USD  English
# ...

# %%
df.set_index("title", inplace=True)

# %%
df.head()
# Out:
#                                               industry  release_year  \
# title
# The Great Dictator                           Hollywood          1940
# The Fast and the Furious                     Hollywood          2001
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Pather Panchali                              Bollywood          1955
#
#                                              imdb_rating  \
# title
# The Great Dictator                                   8.4
# The Fast and the Furious                             6.8
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
# Pather Panchali                                      8.3
#
#                                                                        studio  \
# title
# The Great Dictator                           Charles Chaplin Film Corporation
# ...

# %%
df.index
# Out:
# Index(['The Great Dictator', 'The Fast and the Furious',
#        'Doctor Strange in the Multiverse of Madness', 'Thor: The Dark World ',
#        'Pather Panchali', '2 Fast 2 Furious', 'Thor: Ragnarok ',
#        'Thor: Love and Thunder ', 'The Shawshank Redemption', 'Interstellar',
#        'The Pursuit of Happyness', 'Gladiator', 'Titanic',
#        'It's a Wonderful Life', 'Avatar', 'The Godfather', 'The Dark Knight',
#        'Schindler's List', 'Jurassic Park', 'Parasite', 'Avengers: Endgame',
#        'Avengers: Infinity War', 'Captain America: The First Avenger',
#        'Captain America: The Winter Soldier', 'Dilwale Dulhania Le Jayenge',
#        '3 Idiots', 'Kabhi Khushi Kabhie Gham', 'Bajirao Mastani ',
#        'Taare Zameen Par', 'Munna Bhai M.B.B.S.', 'PK', 'Sanju',
#        'The Kashmir Files', 'Bajrangi Bhaijaan', 'Race 3', 'Shershaah',
#        'K.G.F: Chapter 2', 'Pushpa: The Rise - Part 1', 'RRR',
#        'Baahubali: The Beginning'],
# ...

# %%
df.loc["Titanic"]
df.loc[["Titanic","RRR"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.loc["Titanic"]
#       2 df.loc[["Titanic","RRR"]]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# ...

# %%
df.iloc[0]
# Out:
# industry                               Hollywood
# release_year                                1940
# imdb_rating                                  8.4
# studio          Charles Chaplin Film Corporation
# budget                                       2.2
# revenue                                      5.0
# unit                                    Millions
# currency                                     USD
# language                                 English
# Name: The Great Dictator, dtype: object

# %%
df.iloc[0:5]
# Out:
#                                               industry  release_year  \
# title
# The Great Dictator                           Hollywood          1940
# The Fast and the Furious                     Hollywood          2001
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Pather Panchali                              Bollywood          1955
#
#                                              imdb_rating  \
# title
# The Great Dictator                                   8.4
# The Fast and the Furious                             6.8
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
# Pather Panchali                                      8.3
#
#                                                                        studio  \
# title
# The Great Dictator                           Charles Chaplin Film Corporation
# ...

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                           The Great Dictator  Hollywood          1940
# 1                     The Fast and the Furious  Hollywood          2001
# 2  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 3                        Thor: The Dark World   Hollywood          2013
# 4                              Pather Panchali  Bollywood          1955
#
#    imdb_rating                            studio   budget   revenue  \
# 0          8.4  Charles Chaplin Film Corporation      2.2       5.0
# 1          6.8                Universal Pictures     38.0     207.3
# 2          7.0                    Marvel Studios    200.0     954.8
# 3          6.8                    Marvel Studios    165.0     644.8
# 4          8.3         Government of West Bengal  70000.0  100000.0
#
#         unit currency language
# 0   Millions      USD  English
# 1   Millions      USD  English
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)
